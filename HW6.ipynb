# %%
import numpy as np

# %% [markdown]
# #### Задание 1
# Продакт на главной mail.ru решил протестировать в рекомендательной ленте контента вместо карточек со статьями видеоплеер с короткими видео. Нынешний таймспент на юзера в день в среднем равен 25 минут, а стандартная ошибка (SD) равна 156. Мы предполагаем, что в новой версии таймспент на юзера в день изменится на 10%. Средний трафик 20000 человек в день. Посчитайте сколько дней необходимо держать эксперимент при alpha = 5% и
#  beta = 20% .

# %% [markdown]
# Среднее время, проводимое пользователем на сайте с карточками составляет 25 минут. Рассчитаем среднее время при uplift = 10 %

# %%
time_spent_1 = 25
uplift = 0.1
time_spent_2 = round(time_spent_1 * (1 + uplift), 2)
print(time_spent_2)
# Out:
# 27.5

# %% [markdown]
# Ожидаемое среднее время составит 27,5 минут. Рассчитаем размер выборки при <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>&#x3C3;</mi>
#   <mo>=</mo>
#   <mn>156</mn>
#   <mo>,</mo>
#   <mi>&#x3B1;</mi>
#   <mo>=</mo>
#   <mn>0.05</mn>
#   <mo>,</mo>
#   <mi>&#x3B2;</mi>
#   <mo>=</mo>
#   <mn>0.20</mn>
# </math>
# Для расчета времени проведения A/B теста расчитаем необходимый объем двух выборок при помощи калькулятора Sample Size.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Объем выборки для каждой из групп должен составлять 61124 пользователя, или 122248 всего.Рассчитаем продолжительность A/B-теста с учетом средней посещаемости в 20000 пользователей в сутки:

# %%
print(np.ceil(122248 / 20000))
# Out:
# 7.0

# %% [markdown]
# Ответ: продолжительность A/B-эксперимента должна быть 7 дней.

# %% [markdown]
# #### Задание 2
# Наша продуктовая команда в ecommerce магазине планирует запустить тест, направленный на ускорение загрузки сайта. Одна из основных метрик bounce rate в GA = 40%. Мы предполагаем, что при оптимизации сайта она изменится минимум на 20%.Средний трафик 4000 человек в день. Посчитайте сколько нам нужно дней держать эксперимент при alpha = 5% и beta = 20%

# %% [markdown]
# Средний показатель отказа bounce rate составляет 40% или 0.4. Ожидаемое изменение составит 20%. Рассчитаем размер выборки при <math xmlns="http://www.w3.org/1998/Math/MathML">
#   <mi>&#x3B1;</mi>
#   <mo>=</mo>
#   <mn>0.05</mn>
#   <mo>,</mo>
#   <mi>&#x3B2;</mi>
#   <mo>=</mo>
#   <mn>0.20</mn>
# </math> Для расчета времени проведения A/B теста расчитаем необходимый объем выборок для каждой группы. Используем калькулятор Evan's Awesome A/B Tools.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ответ: для каждой из групп должен составлять 592 пользователя, или 1184 пользователей всего. При средней посещаемости в 4000 человек в день, для проведения A/B-теста хватит одного дня.
